# %% [markdown]
# ## Sinais e Sistemas Dinâmicos - Projeto final
# ### Samuel Pordeus - 11400947
# ### Elcius Ferreira - 11400968

# %% [markdown]
# # Relatório do Projeto
# O projeto consiste em segmentar os diferentes instrumentos de uma música. Utilizamos como Sample das *Plotagens* e das demonstrações a música **Come as you are - Nirvana**. O nosso objetivo principal foi separar a voz dos instrumentos, vamos demonstrar ao longo deste relatório o nosso processo de pensamento até chegarmos na solução do problema.

# %% [markdown]
# # Análise do arquivo de áudio
# ### Importando os módulos necessários

# %%
import scipy.io.wavfile
import pydub
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import mlab
import pylab as pl
from pydub import AudioSegment
from pydub.playback import play

# %matplotlib inline

# %% [markdown]
# Abaixo importamos a música que vai ser processada pelo programa utilizando o módulo SciPy:

# %%
rate,audData=scipy.io.wavfile.read("wav/nirvana.wav")

# %% [markdown]
# Checando o tamanho da música em segundos:

# %%
length = audData.shape[0] / rate
length
# Out:
# 225.69795918367348

# %% [markdown]
# Aqui temos de separar a música em dois canais, pois ela é Stereo. Optamos por não transformar o áudio em mono, pois ao utilizar o recurso da SciPy para isto, causamos um grande dano ao arquivo de áudio, depois da fase de análise, utilizaremos a biblioteca pydub para realizar esta tarefa.

# %%
channel1=audData[:,0] #left
channel2=audData[:,1] #right

# %% [markdown]
# Checando algumas propriedades do arquivo de som, respectivamente, o tipo de variável e a energia do arquivo de áudio:

# %%
audData.dtype
# Out:
# dtype('int16')

# %%
np.sum(channel1.astype(float)**2)
# Out:
# 50712767452163.0

# %% [markdown]
# ### Amplitude de som vs Tempo

# %%
#create a time variable in seconds
time = np.arange(0, float(audData.shape[0]), 1) / rate

#plot amplitude (or loudness) over time
plt.figure(1, figsize=(20,8))
plt.plot(time, channel1, linewidth=0.01, alpha=0.7, color='black')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')

# %% [markdown]
# # Utilizando a fast fourier transform no arquivo de som

# %%
from numpy import fft as fft

fourier=fft.fft(channel1)

plt.figure(1, figsize=(10,5))
plt.plot(fourier, color='#ff7f00')
plt.xlabel('k')
plt.ylabel('Amplitude')
# Out:
# /home/samuelspordeus/anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py:531: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# # Plotando dB vs kHz

# %%
n = len(channel1)
fourier = fourier[0:int(n/2)]

# scale by the number of points so that the magnitude does not depend on the length
fourier = fourier / float(n)

#calculate the frequency at each point in Hz
freqArray = np.arange(0, (n/2), 1.0) * (rate*1.0/n);

plt.figure(1, figsize=(15,5))
plt.plot(freqArray/1000, 10*np.log10(fourier), color ='blue', linewidth=0.02)
plt.xlabel('Frequency (kHz)')
plt.ylabel('Power (dB)')
# Out:
# /home/samuelspordeus/anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py:531: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# # Spectrograma

# %%
plt.figure(1, figsize=(25,10))
Pxx, freqs, bins, im = plt.specgram(channel1, Fs=rate, vmin=0, NFFT=1024, cmap=plt.get_cmap('nipy_spectral'), window=mlab.window_hanning)
cbar=plt.colorbar(im)
plt.xlabel('Time (s)')
plt.ylabel('Frequency (Hz)')
cbar.set_label('Intensity dB')
# plt.savefig("/home/samuelspordeus/fft.pdf", dpi = 200)
# Out:
# /home/samuelspordeus/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:7222: RuntimeWarning: divide by zero encountered in log10
#   Z = 10. * np.log10(spec)

# %% [markdown]
# # Zoom nas frequencias mais baixas

# %%
plt.figure(1, figsize=(50,5))
Pxx, freqs, bins, im = plt.specgram(channel1, Fs=rate, vmin=0, NFFT=1024, cmap=plt.get_cmap('nipy_spectral'), window=mlab.window_hanning)
cbar=plt.colorbar(im)
plt.axis([0, length, 0, 2000])
plt.xlabel('Time (s)')
plt.ylabel('Frequency (Hz)')
cbar.set_label('Intensity dB')
plt.savefig("/home/samuelspordeus/speczoom.png", dpi = 400)
# Out:
# /home/samuelspordeus/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:7222: RuntimeWarning: divide by zero encountered in log10
#   Z = 10. * np.log10(spec)

# %% [markdown]
# # Mapeando frequências entre 430 e 1076

# %%
plt.figure(1, figsize=(25,5))
np.where(np.logical_and(freqs>=430.6640625, freqs<=1076.66015625))
MHZ10=Pxx[233,:]
plt.xlabel('Time')
plt.ylabel('Power')
plt.plot(bins, MHZ10, color='green')

# %% [markdown]
# # A segmentação da voz
# Informações que temos ao nosso favor:
# * Sabemos, lendo estudos realizados em cima das músicas de Nirvana, que a voz de Kurt Cobain tem um range de 61hz-1046hz, pois ele vai de B1 a C6 em notas musicais.
# * Dificilmente a voz de um cantor masculino passa de 1000hz, mas, pelo que analisamos no spectrograma da nossa *Sample*, boa parte do tempo a voz do cantor fica numa faixa mais central, entre 500-700.
#
# Para separarmos a voz dos instrumentos, adotamos duas etapas:
#
# 1. Presumindo que a voz estava nos centros dos canais Stereo, utilizamos deste fato para suprimirmos a voz do cantor.
# 2. Utilizamos um filtro passa-baixo, utilizando como frequencia de corte um valor que achamos o ideal após analisarmos cuidadosamente o spectograma e conseguirmos discernir em que faixa estava a voz de **Kurt**

# %% [markdown]
# ## Primeira etapa: Remover os centros do arquivo Stereo (Opcional)
# Ao transformarmos o canal em mono e após analisarmos cuidadosamente os dois canais do arquivo estéreo utilizando uma versão de alta resolução do nosso spectrograma, vimos que era possível utilizar essa técnica para suprimir a voz do cantor.
#
# Utilizamos a biblioteca PyDub, que contém diversas funções para tratamento de áudio.

# %%
musica = AudioSegment.from_file("wav/nirvana.wav", format="wav")

musica_L = musica.split_to_mono()[0]
musica_R = musica.split_to_mono()[1]

musica_R_inv = musica_R.invert_phase()
musica_centersOut = musica_L.overlay(musica_R_inv)

fh = musica_centersOut.export("centersout.wav", format="wav")

# %% [markdown]
# # Segunda etapa: Filtro passa-baixo
#
# Pegamos o arquivo com os centros removidos e aplicamos um filtro passa-baixo com uma frequencia de corte de **400hz**

# %%
import wave, sys, math, contextlib

fname = 'centersout.wav'
outname = 'filtered.wav'

cutOffFrequency = 400.0

def running_mean(x, windowSize):
  cumsum = np.cumsum(np.insert(x, 0, 0)) 
  return (cumsum[windowSize:] - cumsum[:-windowSize]) / windowSize

dfef interpret_wav(raw_bytes, n_frames, n_channels, sample_width, interleaved = True):

    if sample_width == 1:
        dtype = np.uint8 # unsigned char
    elif sample_width == 2:
        dtype = np.int16 # signed 2-byte short
    else:
        raise ValueError("Only supports 8 and 16 bit audio formats.")

    channels = np.fromstring(raw_bytes, dtype=dtype)

    if interleaved:
        # channels are interleaved, i.e. sample N of channel M follows sample N of channel M-1 in raw data
        channels.shape = (n_frames, n_channels)
        channels = channels.T
    else:
        # channels are not interleaved. All samples from channel M occur before all samples from channel M-1
        channels.shape = (n_channels, n_frames)

    return channels

with contextlib.closing(wave.open(fname,'rb')) as spf:
    sampleRate = spf.getframerate()
    ampWidth = spf.getsampwidth()
    nChannels = spf.getnchannels()
    nFrames = spf.getnframes()

    # Extract Raw Audio from multi-channel Wav File
    signal = spf.readframes(nFrames*nChannels)
    spf.close()
    channels = interpret_wav(signal, nFrames, nChannels, ampWidth, True)

    # get window size
    freqRatio = (cutOffFrequency/sampleRate)
    N = int(math.sqrt(0.196196 + freqRatio**2)/freqRatio)

    # Use moviung average (only on first channel)
    filtered = running_mean(channels[0], N).astype(channels.dtype)

    wav_file = wave.open(outname, "w")
    wav_file.setparams((1, ampWidth, sampleRate, nFrames, spf.getcomptype(), spf.getcompname()))
    wav_file.writeframes(filtered.tobytes('C'))
    wav_file.close()

# %% [markdown]
# ### O arquivo de output foi salvo na mesma pasta que esse ipynb se encontra com o nome: *filtered.wav*

# %% [markdown]
# # Spectrograma do novo arquivo de audio

# %%
new_rate,new_audData=scipy.io.wavfile.read("filtered.wav")

# %%
plt.figure(1, figsize=(25,10))
Pxx, freqs, bins, im = plt.specgram(new_audData, Fs=new_rate, vmin=0, NFFT=1024, cmap=plt.get_cmap('nipy_spectral'), window=mlab.window_hanning)
cbar=plt.colorbar(im)
plt.axis([0, length, 0, 7500])
plt.xlabel('Time (s)')
plt.ylabel('Frequency (Hz)')
cbar.set_label('Intensity dB')
plt.savefig("/home/samuelspordeus/fft.pdf", dpi = 200)
# Out:
# /home/samuelspordeus/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:7222: RuntimeWarning: divide by zero encountered in log10
#   Z = 10. * np.log10(spec)

# %% [markdown]
# # Processo reverso
# Poderiamos fazer o processo reverso, ou seja, separar apenas a voz do cantor no arquivo **WAV**, de forma análoga à exposta aqui. Por exemplo, utilizando um filtro passa-altas de 400hz, claro que uma análise mais detalhada do spectrograma ajudaria na eficácia do filtro.

# %% [markdown]
# # Formas de aumentar a precisão
# Não encontramos uma maneira linear de filtrar/segmentar instrumentos musicais, porém pensamos em uma maneira muito interessante de separar os instrumentos de uma música:
#
# Utilizando aprendizado de máquina não-supervisionado, com uma clusterização para separar as diferentes faixas de frequências que contivessem instrumentos. Tendo *samples* destes instrumentos como modelos de treinamento, poderiamos tentar filtrar qualquer música. Entretanto, um trabalho de tamanha complexidade seria digno de um TCC.

# %% [markdown]
# # Considerações finais
# Infelizmente, apesar de sabermos como funciona o processo na teoria, não conseguimos segmentar a voz em um arquivo de áudio separado, devido a forma em que os arquivos de áudio são tratados pelas bibliotecas que utilizamos no processo. Contudo, tivemos uma grande 'ajuda' do Spectrograma na ajustagem do parâmetro da frequencia de corte.
#
# Dito isso tudo, aprendemos bastante sobre filtros, pois tivemos que estudar muitos conceitos aprendidos em sala, que nos pareciam distantes da realidade, novamente. Vê-los sendo aplicados na prática edificou o nosso conhecimento no assunto.
